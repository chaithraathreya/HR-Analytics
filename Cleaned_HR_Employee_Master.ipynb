# %%
import pandas as pd
import numpy as np

df=pd.read_csv("C:/Users/chait/Desktop/HR_Analytics_Personal/HR_Employee_Master.csv")

# %%
df.head()
# Out:
#   EmployeeID        FullName                Department         JobTitle  \
# 0   PNR-1001    Olivia Brown                     Sales  Account Manager
# 1   PNR-1002   John Williams    Research & Development    Research Lead
# 2   PNR-1003    Olivia Singh          Quality Control        QC Manager
# 3   PNR-1004  Chris Williams   Research & Development               NaN
# 4   PNR-1004  Chris Williams    Research & Development    Research Lead
#
#                      Email      Gender    HireDate TerminationDate    Salary  \
# 0  employee.1001@pnrao.com  Non-binary  2024-05-10             NaN  177617.0
# 1  employee.1002@pnrao.com      Female  2020-03-06             NaN       NaN
# 2  employee.1003@pnrao.com      Female  2025-10-14             NaN  179304.0
# 3  employee.1004@pnrao.com         NaN  2019-02-22      2024-02-07   94033.0
# 4  employee.1004@pnrao.com      Female  2019-02-22      2024-02-07   94033.0
#
#    ManagerID  PerformanceRating      Status
# ...

# %%
df.tail()
# Out:
#       EmployeeID        FullName    Department               JobTitle  \
# 49995  PNR-50996      John Brown     Logistics  Logistics Coordinator
# 49996  PNR-50997     Chris Jones     Marketing                    NaN
# 49997  PNR-50998   Aditya Smith     Production      Production Worker
# 49998  PNR-50999             NaN   Production       Production Worker
# 49999  PNR-51000    Saanvi Jones       Finance      Financial Analyst
#
#                             Email      Gender      HireDate TerminationDate  \
# 49995    employee.50996@pnrao.com         NaN    2020-07-26             NaN
# 49996                         NaN  Non-binary    2022-02-16
# 49997    employee.50998@pnrao.com      Female   2021-05-11              NaN
# 49998   employee.50999@pnrao.com          NaN   2020-06-16              NaN
# 49999    employee.51000@pnrao.com      Female    2020-09-08             NaN
#
#         Salary    ManagerID  PerformanceRating    Status
# ...

# %%
df.describe()
# Out:
#               Salary  PerformanceRating
# count   45725.000000       45817.000000
# mean    91121.547928           3.510182
# std     36303.586655           1.113687
# min     55000.000000           2.000000
# 25%     65506.000000           3.000000
# 50%     75936.000000           4.000000
# 75%    120658.000000           5.000000
# max    180000.000000           5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         44549 non-null  object
#  1   FullName           44675 non-null  object
#  2   Department         44529 non-null  object
#  3   JobTitle           44674 non-null  object
#  4   Email              44718 non-null  object
#  5   Gender             44572 non-null  object
#  6   HireDate           44589 non-null  object
#  7   TerminationDate    11421 non-null  object
#  8   Salary             45725 non-null  float64
#  9   ManagerID          35159 non-null  object
#  10  PerformanceRating  45817 non-null  float64
#  11  Status             44626 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 4.6+ MB

# %%
df.shape
# Out:
# (50000, 12)

# %%
df.isnull().sum()
# Out:
# EmployeeID            5451
# FullName              5325
# Department            5471
# JobTitle              5326
# Email                 5282
# Gender                5428
# HireDate              5411
# TerminationDate      38579
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
import uuid

df.loc[df['EmployeeID'].isna(), 'EmployeeID'] = [
    uuid.uuid4().hex for _ in range(df['EmployeeID'].isna().sum())
]

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName              5325
# Department            5471
# JobTitle              5326
# Email                 5282
# Gender                5428
# HireDate              5411
# TerminationDate      38579
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['FullName'] = df['FullName'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department            5471
# JobTitle              5326
# Email                 5282
# Gender                5428
# HireDate              5411
# TerminationDate      38579
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['Department'] = df['Department'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle              5326
# Email                 5282
# Gender                5428
# HireDate              5411
# TerminationDate      38579
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['JobTitle'] = df['JobTitle'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                 5282
# Gender                5428
# HireDate              5411
# TerminationDate      38579
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['Email'] = df['Email'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                5428
# HireDate              5411
# TerminationDate      38579
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['Gender'] = df['Gender'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                   0
# HireDate              5411
# TerminationDate      38579
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['HireDate'] = df['HireDate'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                   0
# HireDate                 0
# TerminationDate      38579
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['TerminationDate'] = df['TerminationDate'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                   0
# HireDate                 0
# TerminationDate          0
# Salary                4275
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['Salary'] = df['Salary'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                   0
# HireDate                 0
# TerminationDate          0
# Salary                   0
# ManagerID            14841
# PerformanceRating     4183
# Status                5374
# dtype: int64

# %%
df['PerformanceRating'] = df['PerformanceRating'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                   0
# HireDate                 0
# TerminationDate          0
# Salary                   0
# ManagerID            14841
# PerformanceRating        0
# Status                5374
# dtype: int64

# %%
df['Status'] = df['Status'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                   0
# HireDate                 0
# TerminationDate          0
# Salary                   0
# ManagerID            14841
# PerformanceRating        0
# Status                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 302

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# EmployeeID           object
# FullName             object
# Department           object
# JobTitle             object
# Email                object
# Gender               object
# HireDate             object
# TerminationDate      object
# Salary               object
# ManagerID            object
# PerformanceRating    object
# Status               object
# dtype: object

# %%
df.head()
# Out:
#   EmployeeID        FullName                Department         JobTitle  \
# 0   PNR-1001    Olivia Brown                     Sales  Account Manager
# 1   PNR-1002   John Williams    Research & Development    Research Lead
# 2   PNR-1003    Olivia Singh          Quality Control        QC Manager
# 3   PNR-1004  Chris Williams   Research & Development           Unknown
# 4   PNR-1004  Chris Williams    Research & Development    Research Lead
#
#                      Email      Gender    HireDate TerminationDate    Salary  \
# 0  employee.1001@pnrao.com  Non-binary  2024-05-10         Unknown  177617.0
# 1  employee.1002@pnrao.com      Female  2020-03-06         Unknown   Unknown
# 2  employee.1003@pnrao.com      Female  2025-10-14         Unknown  179304.0
# 3  employee.1004@pnrao.com     Unknown  2019-02-22      2024-02-07   94033.0
# 4  employee.1004@pnrao.com      Female  2019-02-22      2024-02-07   94033.0
#
#    ManagerID PerformanceRating      Status
# ...

# %%
df['EmployeeID'] = df['EmployeeID'].astype('string')

# %%
df.dtypes
# Out:
# EmployeeID           string[python]
# FullName                     object
# Department                   object
# JobTitle                     object
# Email                        object
# Gender                       object
# HireDate                     object
# TerminationDate              object
# Salary                       object
# ManagerID                    object
# PerformanceRating            object
# Status                       object
# dtype: object

# %%
df['FullName'] = df['FullName'].astype('string')

# %%
df['Department'] = df['Department'].astype('string')

# %%
df['JobTitle'] = df['JobTitle'].astype('string')

# %%
df['Email'] = df['Email'].astype('string')

# %%
df['Gender'] = df['Gender'].astype('category')

# %%
df['HireDate'] = pd.to_datetime(df['HireDate'], errors='coerce')

# %%
df['TerminationDate'] = pd.to_datetime(df['TerminationDate'], errors='coerce')
# Out:
# C:\Users\chait\AppData\Local\Temp\ipykernel_1860\2596958650.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['TerminationDate'] = pd.to_datetime(df['TerminationDate'], errors='coerce')

# %%
df['TerminationDate'] = (
    pd.to_datetime(df['TerminationDate'], dayfirst=True, errors='coerce')
)

# %%
df['Salary'] = pd.to_numeric(df['Salary'], errors='coerce')

# %%
df['ManagerID'] = df['ManagerID'].astype('string')

# %%
df['PerformanceRating'] = pd.to_numeric(df['PerformanceRating'], errors='coerce')

# %%
df['Status'] = df['Status'].astype('category')

# %%
df.dtypes
# Out:
# EmployeeID           string[python]
# FullName             string[python]
# Department           string[python]
# JobTitle             string[python]
# Email                string[python]
# Gender                     category
# HireDate             datetime64[ns]
# TerminationDate      datetime64[ns]
# Salary                      float64
# ManagerID            string[python]
# PerformanceRating           float64
# Status                     category
# dtype: object

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                   0
# HireDate             10985
# TerminationDate      43034
# Salary                4275
# ManagerID            14766
# PerformanceRating     4183
# Status                   0
# dtype: int64

# %%
# Already handled if you used errors='coerce'
df['HireDate'] = pd.to_datetime(df['HireDate'], errors='coerce')

# %%
df['HireDate'].isnull().sum()
# Out:
# 10985

# %%
df['TerminationDate'] = pd.to_datetime(df['TerminationDate'], errors='coerce')

# %%
df['TerminationDate'].isnull().sum()
# Out:
# 43034

# %%
df.loc[df['Salary'].isna(), 'Salary'].unique()
# Out:
# array([nan])

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())

# %%
df['Salary'].isnull().sum()
# Out:
# 0

# %%
df.loc[df['PerformanceRating'].isna(), 'PerformanceRating'].unique()
# Out:
# array([nan])

# %%
df['PerformanceRating'] = df['PerformanceRating'].fillna(df['PerformanceRating'].median())

# %%
df['PerformanceRating'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# EmployeeID               0
# FullName                 0
# Department               0
# JobTitle                 0
# Email                    0
# Gender                   0
# HireDate             10985
# TerminationDate      43034
# Salary                   0
# ManagerID            14766
# PerformanceRating        0
# Status                   0
# dtype: int64

# %%
df = df.where(pd.notnull(df), None)

# %%
df.to_csv("cleaned_HR_Employee_data.csv", index=False)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
before = df.shape[0]
df.drop_duplicates(inplace=True)
after = df.shape[0]

# %%
print(f"Removed {before - after} duplicate rows")
# Out:
# Removed 0 duplicate rows

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (49637, 12)

# %%
df.head()
# Out:
#   EmployeeID        FullName                Department         JobTitle  \
# 0   PNR-1001    Olivia Brown                     Sales  Account Manager
# 1   PNR-1002   John Williams    Research & Development    Research Lead
# 2   PNR-1003    Olivia Singh          Quality Control        QC Manager
# 3   PNR-1004  Chris Williams   Research & Development           Unknown
# 4   PNR-1004  Chris Williams    Research & Development    Research Lead
#
#                      Email      Gender   HireDate TerminationDate    Salary  \
# 0  employee.1001@pnrao.com  Non-binary 2024-05-10             NaT  177617.0
# 1  employee.1002@pnrao.com      Female 2020-03-06             NaT   75932.0
# 2  employee.1003@pnrao.com      Female 2025-10-14             NaT  179304.0
# 3  employee.1004@pnrao.com     Unknown 2019-02-22      2024-02-07   94033.0
# 4  employee.1004@pnrao.com      Female 2019-02-22      2024-02-07   94033.0
#
#    ManagerID  PerformanceRating      Status
# ...
